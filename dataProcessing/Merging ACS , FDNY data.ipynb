# %% [markdown]
# <h1><center>MERGE ACS DATA WITH FDNY DATA BY GEOID</center></h1>

# %%
import glob
import pandas as pd
import numpy as np
from os import listdir
from os.path import isfile, join

years = [str(i) for i in range(2010, 2019)]
path_from = 'C:\\Users\\mskac\\machineLearning\\GasLeakConEd\\data\\processed\\acs_data\\'
path_to = 'C:\\Users\\mskac\\machineLearning\\GasLeakConEd\\data\\processed\\merged_acs_data\\'
base_path = 'C:/Users/mskac/machineLearning/GasLeakConEd/data/'

files = ['acs_merged_data' + str(year) + '.csv' for year in range(2010, 2019)]

# %%
dfs_acs_original = [pd.read_csv(join(path_to, files[i])) for i in range(9)]
for i in range(len(dfs_acs_original)):
    dfs_acs_original[i]['incident_year'] = 2010 +i

# %%
# we will have all years information in one dataframe to merge it with gas info
df_acs = pd.concat(dfs_acs_original, ignore_index = True)
df_acs['geoid'] = df_acs['geoid'].astype('int64')

# %%
df_gas = pd.read_csv(base_path+ 'processed\FULL_fdny_2013_2020.csv')
df_gas['geoid'] = df_gas['geoid'].astype('int64')

# %%
df_gas_ = df_gas
df_gas_['incident_year'] = df_gas['incident_date_time'].str[6:10]
df_gas_['count'] = 1
df_gas_.head()
# Out:
#    Unnamed: 0        geoid fire_box  \
# 0           0  36047040000    B4235
# 1           1  36047069602    B3183
# 2           2  36047052000    B2475
# 3           3  36047035300    B1012
# 4           4  36047007100    B0582
#
#                                             ntaname  boroname  \
# 0                                  Bensonhurst East  Brooklyn
# 1    Georgetown-Marine Park-Bergen Beach-Mill Basin  Brooklyn
# 2                                          Flatbush  Brooklyn
# 3                               Crown Heights North  Brooklyn
# 4  DUMBO-Vinegar Hill-Downtown Brooklyn-Boerum Hill  Brooklyn
#
#        incident_date_time  engines_assigned_quantity  total_incident_duration  \
# 0  01/06/2013 07:05:52 PM                          2                     1035
# 1  01/13/2013 07:21:51 AM                          3                     1469
# 2  07/30/2017 04:40:45 PM                          2                      481
# 3  02/24/2020 10:11:19 AM                          2                      558
# 4  12/19/2019 10:18:32 AM                          2                     1158
#
#   incident_year  count
# 0          2013      1
# 1          2013      1
# 2          2017      1
# 3          2020      1
# 4          2019      1

# %%
df_gas_ = df_gas_.groupby(['incident_year', 'geoid']).agg({'engines_assigned_quantity': 'mean', 'total_incident_duration': 'mean', 'count': 'count'}).reset_index()

# %%
df_gas_.head()
# Out:
#   incident_year        geoid  engines_assigned_quantity  \
# 0          2013  36005000200                   2.000000
# 1          2013  36005000400                   2.200000
# 2          2013  36005001600                   2.272727
# 3          2013  36005001900                   2.000000
# 4          2013  36005002000                   2.357143
#
#    total_incident_duration  count
# 0              1041.000000      2
# 1              1351.000000      5
# 2              1720.636364     11
# 3              1170.000000      3
# 4              1260.523810     42

# %%
df_gas_['incident_year'] = df_gas_['incident_year'].astype('int64')
df_acs['incident_year'] = df_acs['incident_year'].astype('int64')

# %%
merged_dfs = df_acs.merge(df_gas_, how='inner', on = ['incident_year','geoid'], validate="one_to_one")
merged_dfs = merged_dfs.sort_values(by = ['incident_year', 'geoid'])
merged_dfs.columns.to_list()
# Out:
# ['Unnamed: 0',
#  'avg_houshold_size',
#  'nonfamily_housholds%',
#  'lonely_housholder%',
#  'lonely_housholder_over65%',
#  'housholders_grandparents_responsible_for_grandchildren%',
#  'not_us_citizen(abs, people)',
#  'geoid',
#  'unemployed%',
#  'median_houshold_income',
#  'mean_houshold_income',
#  'total_housing_units',
#  'avg_year_built',
#  'occupied_housing_units%',
#  'vacant_housing_units%',
#  'total_population',
#  'median_age',
#  'not_us_citizen%',
#  'incident_year',
#  'engines_assigned_quantity',
#  'total_incident_duration',
#  'count']

# %%
merged_dfs['gas_leaks_per_person'] = merged_dfs['count']/merged_dfs['total_population']
merged_dfs['gas_leaks_per_person'] = merged_dfs['count']/merged_dfs['total_population']

merged_dfs.rename(columns={'engines_assigned_quantity':'avg_assigned_fdny_engines#',
                          'total_incident_duration':'avg_incident_duration'}, inplace = True)
columns = ['incident_year','geoid','gas_leaks_per_person','avg_assigned_fdny_engines#',
 'avg_incident_duration',
 'median_age','avg_houshold_size', 'avg_year_built',
 'nonfamily_housholds%',
 'lonely_housholder%',
 'lonely_housholder_over65%',
 'housholders_grandparents_responsible_for_grandchildren%',
 'unemployed%',
 'median_houshold_income',
 'mean_houshold_income',
 'total_housing_units',
 'occupied_housing_units%',
 'vacant_housing_units%',
 'not_us_citizen%',
 ]

# %%
merged_dfs = merged_dfs[columns]
merged_dfs[merged_dfs < 0] = None
merged_dfs.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 11607 entries, 0 to 10045
# Data columns (total 19 columns):
#  #   Column                                                   Non-Null Count  Dtype
# ---  ------                                                   --------------  -----
#  0   incident_year                                            11607 non-null  int64
#  1   geoid                                                    11607 non-null  int64
#  2   gas_leaks_per_person                                     11607 non-null  float64
#  3   avg_assigned_fdny_engines#                               11607 non-null  float64
#  4   avg_incident_duration                                    11607 non-null  float64
#  5   median_age                                               11590 non-null  float64
#  6   avg_houshold_size                                        11595 non-null  float64
#  7   avg_year_built                                           11607 non-null  float64
#  8   nonfamily_housholds%                                     11604 non-null  float64
#  9   lonely_housholder%                                       11604 non-null  float64
#  10  lonely_housholder_over65%                                11604 non-null  float64
#  11  housholders_grandparents_responsible_for_grandchildren%  11604 non-null  float64
#  12  unemployed%                                              11602 non-null  float64
#  13  median_houshold_income                                   11556 non-null  float64
#  14  mean_houshold_income                                     11577 non-null  float64
#  15  total_housing_units                                      11607 non-null  int64
#  16  occupied_housing_units%                                  11607 non-null  float64
#  17  vacant_housing_units%                                    11607 non-null  float64
#  18  not_us_citizen%                                          11605 non-null  float64
# dtypes: float64(16), int64(3)
# memory usage: 1.8 MB

# %%
merged_dfs.to_csv(base_path+ 'processed\important_(used_in_app)\Merged_asc_fdny_data.csv')

# %%
merged_dfs.head(5000)
# Out:
#       incident_year        geoid  gas_leaks_per_person  \
# 0              2013  36005000200              0.000412
# 1              2013  36005000400              0.000936
# 2              2013  36005001600              0.002109
# 3              2013  36005001900              0.001171
# 4              2013  36005002000              0.004967
# ...             ...          ...                   ...
# 5084           2015  36061021303              0.003450
# 5085           2015  36061021400              0.012970
# 5086           2015  36061021500              0.010916
# 5087           2015  36061021600              0.002734
# 5088           2015  36061021703              5.625000
#
#       avg_assigned_fdny_engines#  avg_incident_duration  median_age  \
# 0                       2.000000            1041.000000        34.5
# 1                       2.200000            1351.000000        35.2
# 2                       2.272727            1720.636364        39.2
# 3                       2.000000            1170.000000        30.5
# 4                       2.357143            1260.523810        35.9
# ...                          ...                    ...         ...
# 5084                    1.952381            1237.714286        35.9
# 5085                    2.102564            1216.692308        45.2
# 5086                    1.878049            1226.219512        29.2
# 5087                    1.826087            1161.217391        36.4
# 5088                    2.044444            1393.577778         NaN
#
#       avg_houshold_size  nonfamily_housholds%  lonely_housholder%  \
# 0                  3.60             19.005197           18.040089
# 1                  3.04             18.881917           13.519681
# 2                  2.55             34.035990           33.470437
# 3                  2.60             44.645006           35.499398
# 4                  2.84             29.798658           28.624161
# ...                 ...                   ...                 ...
# 5084               2.66             52.376600           37.934186
# 5085               1.59             76.744186           70.137421
# 5086               2.80             42.136945           33.032355
# 5087               2.44             56.506132           41.160634
# 5088               2.00              0.000000            0.000000
#
#       lonely_housholder_over65%  \
# 0                     11.210097
# 1                      7.187678
# 2                     13.984576
# 3                      2.406739
# 4                     12.953020
# ...                         ...
# 5084                   6.444241
# 5085                  20.031712
# 5086                  10.007524
# 5087                   9.991026
# 5088                   0.000000
#
#       housholders_grandparents_responsible_for_grandchildren%  unemployed%  \
# 0                                              9.576837                8.5
# 1                                              4.164290                5.7
# 2                                              1.748072                6.6
# 3                                              0.000000               18.5
# 4                                              6.241611               13.5
# ...                                                 ...                ...
# 5084                                           3.930530                4.1
# 5085                                           1.585624               11.0
# 5086                                           2.182092                9.6
# 5087                                           1.465749                8.2
# 5088                                           0.000000                0.0
#
#       median_houshold_income  mean_houshold_income  total_housing_units  \
# 0                    69514.0               72652.0                 1476
# 1                    73036.0               80733.0                 1912
# 2                    30817.0               44609.0                 2043
# 3                    33862.0               42285.0                  891
# 4                    19150.0               34044.0                 3161
# ...                      ...                   ...                  ...
# 5084                 37628.0               48354.0                 2443
# 5085                 44405.0               47293.0                 2026
# 5086                 33477.0               46489.0                 1459
# 5087                 46250.0               85416.0                 3771
# 5088                     NaN                   NaN                    4
#
#       occupied_housing_units%  vacant_housing_units%  not_us_citizen%
# 0                        91.3                    8.7        11.198024
# 1                        91.7                    8.3         7.821856
# 2                        95.2                    4.8        15.819751
# 3                        93.3                    6.7        24.863388
# 4                        94.3                    5.7         9.425260
# ...                       ...                    ...              ...
# 5084                     89.6                   10.4        24.511253
# 5085                     93.4                    6.6        10.375790
# 5086                     91.1                    8.9        16.959531
# 5087                     88.7                   11.3         9.211934
# 5088                    100.0                    0.0         0.000000
#
# [5000 rows x 18 columns]

# %%
df_gas_ = df_gas
df_gas_['incident_year'] = df_gas['incident_date_time'].str[6:10]
df_gas_['incident_month'] = df_gas['incident_date_time'].str[:2]
df_gas_['count'] = 1
df_gas_.head()
# Out:
#    Unnamed: 0        geoid fire_box  \
# 0           0  36047040000    B4235
# 1           1  36047069602    B3183
# 2           2  36047052000    B2475
# 3           3  36047035300    B1012
# 4           4  36047007100    B0582
#
#                                             ntaname  boroname  \
# 0                                  Bensonhurst East  Brooklyn
# 1    Georgetown-Marine Park-Bergen Beach-Mill Basin  Brooklyn
# 2                                          Flatbush  Brooklyn
# 3                               Crown Heights North  Brooklyn
# 4  DUMBO-Vinegar Hill-Downtown Brooklyn-Boerum Hill  Brooklyn
#
#        incident_date_time  engines_assigned_quantity  total_incident_duration  \
# 0  01/06/2013 07:05:52 PM                          2                     1035
# 1  01/13/2013 07:21:51 AM                          3                     1469
# 2  07/30/2017 04:40:45 PM                          2                      481
# 3  02/24/2020 10:11:19 AM                          2                      558
# 4  12/19/2019 10:18:32 AM                          2                     1158
#
#   incident_year  count incident_month
# 0          2013      1             01
# 1          2013      1             01
# 2          2017      1             07
# 3          2020      1             02
# 4          2019      1             12

# %%
df_gas_ = df_gas_.groupby(['incident_year', 'incident_month','geoid']).agg({'engines_assigned_quantity': 'mean', 'total_incident_duration': 'mean', 'count': 'count'}).reset_index()

# %%
df_gas_.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 79776 entries, 0 to 79775
# Data columns (total 6 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   incident_year              79776 non-null  object
#  1   incident_month             79776 non-null  object
#  2   geoid                      79776 non-null  int64
#  3   engines_assigned_quantity  79776 non-null  float64
#  4   total_incident_duration    79776 non-null  float64
#  5   count                      79776 non-null  int64
# dtypes: float64(2), int64(2), object(2)
# memory usage: 3.7+ MB

# %%
df_gas_['incident_year'] = df_gas_['incident_year'].astype('int64')
df_acs['incident_year'] = df_acs['incident_year'].astype('int64')
df_gas_['incident_month'] = df_gas_['incident_month'].astype('int64')

# %%
merged_dfs = df_gas_.merge(df_acs, how='left', on = ['incident_year','geoid'])
merged_dfs = merged_dfs.sort_values(by = ['incident_year', 'incident_month','geoid'])
merged_dfs.columns.to_list()
# Out:
# ['incident_year',
#  'incident_month',
#  'geoid',
#  'engines_assigned_quantity',
#  'total_incident_duration',
#  'count',
#  'Unnamed: 0',
#  'avg_houshold_size',
#  'nonfamily_housholds%',
#  'lonely_housholder%',
#  'lonely_housholder_over65%',
#  'housholders_grandparents_responsible_for_grandchildren%',
#  'not_us_citizen(abs, people)',
#  'unemployed%',
#  'median_houshold_income',
#  'mean_houshold_income',
#  'total_housing_units',
#  'avg_year_built',
#  'occupied_housing_units%',
#  'vacant_housing_units%',
#  'total_population',
#  'median_age',
#  'not_us_citizen%']

# %%
merged_dfs.head(50)
# Out:
#     incident_year  incident_month        geoid  engines_assigned_quantity  \
# 0            2013               1  36005002000                   2.333333
# 1            2013               1  36005002400                   2.000000
# 2            2013               1  36005002500                   2.000000
# 3            2013               1  36005002701                   2.000000
# 4            2013               1  36005002800                   2.000000
# 5            2013               1  36005003500                   2.500000
# 6            2013               1  36005004001                   2.000000
# 7            2013               1  36005004100                   2.000000
# 8            2013               1  36005004200                   2.000000
# 9            2013               1  36005004300                   2.000000
# 10           2013               1  36005004600                   2.500000
# 11           2013               1  36005004800                   2.000000
# 12           2013               1  36005005001                   2.000000
# 13           2013               1  36005005002                   2.000000
# 14           2013               1  36005005200                   1.000000
# 15           2013               1  36005006000                   1.000000
# 16           2013               1  36005006100                   2.000000
# 17           2013               1  36005006200                   3.000000
# 18           2013               1  36005006400                   2.000000
# 19           2013               1  36005006500                   2.000000
# 20           2013               1  36005006700                   2.000000
# 21           2013               1  36005006800                   2.500000
# 22           2013               1  36005006900                   2.000000
# 23           2013               1  36005007200                   0.000000
# 24           2013               1  36005007300                   2.000000
# 25           2013               1  36005007400                   2.000000
# 26           2013               1  36005007500                   2.000000
# 27           2013               1  36005007700                   3.000000
# 28           2013               1  36005007900                   2.000000
# 29           2013               1  36005008600                   2.750000
# 30           2013               1  36005008700                   1.000000
# 31           2013               1  36005009300                   2.400000
# 32           2013               1  36005009800                   3.000000
# 33           2013               1  36005012101                   2.000000
# 34           2013               1  36005012901                   2.500000
# 35           2013               1  36005013300                   1.500000
# 36           2013               1  36005013500                   2.333333
# 37           2013               1  36005013800                   3.000000
# 38           2013               1  36005014100                   0.000000
# 39           2013               1  36005014400                   2.000000
# 40           2013               1  36005014500                   2.250000
# 41           2013               1  36005014701                   2.333333
# 42           2013               1  36005015100                   2.000000
# 43           2013               1  36005015200                   2.000000
# 44           2013               1  36005016300                   3.000000
# 45           2013               1  36005016600                   2.000000
# 46           2013               1  36005017100                   2.000000
# 47           2013               1  36005017300                   2.000000
# 48           2013               1  36005017500                   2.250000
# 49           2013               1  36005017701                   1.666667
#
#     total_incident_duration  count  Unnamed: 0  avg_houshold_size  \
# 0               1162.833333      6        92.0               2.84
# 1                911.000000      1         NaN                NaN
# 2               1062.000000      1        94.0               2.82
# 3                822.500000      2        95.0               3.00
# 4               6190.000000      1        97.0               2.48
# 5                996.500000      2       100.0               2.91
# 6               1323.000000      1       104.0               3.00
# 7               1203.500000      4       105.0               3.05
# 8               1560.600000      5       106.0               2.75
# 9                757.000000      1       107.0               2.93
# 10              1017.500000      2       109.0               2.44
# 11              1818.000000      1       110.0               3.14
# 12               886.000000      1       111.0               3.23
# 13               986.000000      1       112.0               3.35
# 14              1703.000000      2       114.0               2.66
# 15               746.500000      2       119.0               3.81
# 16              1061.666667      3       120.0               1.83
# 17              1142.000000      1       121.0               3.27
# 18              1195.000000      1       123.0               3.26
# 19              1906.000000      2       124.0               3.06
# 20               997.000000      1       125.0               3.34
# 21              1641.000000      2       126.0               3.05
# 22               970.000000      1       127.0               2.77
# 23              2578.000000      1       130.0               3.37
# 24               843.000000      1       131.0               2.80
# 25               564.000000      1       132.0               2.72
# 26              1749.000000      2       415.0               2.62
# 27              1495.000000      2       417.0               3.08
# 28              1006.666667      3       419.0               2.70
# 29               962.750000      4       423.0               2.59
# 30              1255.000000      2       424.0               3.36
# 31              1136.000000      5       428.0               3.22
# 32               802.000000      1       430.0               2.90
# 33               937.000000      2       436.0               3.37
# 34              1581.000000      2       441.0               2.53
# 35               970.000000      2       445.0               2.98
# 36              1159.166667      6       446.0               2.94
# 37              1982.000000      1       447.0               2.43
# 38              1429.000000      1       448.0               2.40
# 39               971.333333      3       450.0               2.79
# 40               950.000000      4       451.0               2.94
# 41               950.000000      3       452.0               3.24
# 42               981.500000      2       455.0               3.22
# 43               849.000000      2       456.0               3.20
# 44              1064.000000      1         NaN                NaN
# 45              1171.000000      1       467.0               2.92
# 46               544.000000      1         NaN                NaN
# 47               933.000000      4       470.0               2.88
# 48              1112.500000      4       471.0               2.73
# 49              1322.666667      3       472.0               3.12
#
#     nonfamily_housholds%  lonely_housholder%  ...  unemployed%  \
# 0              29.798658           28.624161  ...         13.5
# 1                    NaN                 NaN  ...          NaN
# 2              32.579934           27.177508  ...         12.1
# 3              21.152030           15.391879  ...         18.5
# 4              39.102564           32.649573  ...          9.0
# 5              30.256012           27.618309  ...         14.9
# 6              33.265306           30.000000  ...          9.8
# 7              29.629630           29.234568  ...         16.3
# 8              34.641007           30.977054  ...         23.5
# 9              33.941404           29.187396  ...         14.1
# 10             43.683409           43.074581  ...         21.5
# 11             24.878444           22.366288  ...         15.3
# 12             24.022346           19.413408  ...         15.4
# 13             24.033816           18.900966  ...         11.3
# 14             29.261745           27.114094  ...         19.8
# 15             23.100304           17.021277  ...          7.4
# 16             56.464891           55.786925  ...         19.2
# 17             29.266212           25.213311  ...         14.1
# 18             35.801465           26.932465  ...         17.3
# 19             37.751222           32.971211  ...         10.6
# 20             32.104586           28.332619  ...         19.0
# 21             35.444331           29.622063  ...         21.1
# 22             34.087423           30.099693  ...         21.4
# 23             29.971831           25.971831  ...          9.0
# 24             34.409449           32.283465  ...         22.0
# 25             31.593794           24.894217  ...          7.7
# 26             39.806378           35.990888  ...          7.7
# 27             22.558923           20.033670  ...         13.6
# 28             37.360179           34.854586  ...         23.9
# 29             31.468023           26.380814  ...         11.8
# 30             25.591635           22.399560  ...          9.6
# 31             25.804564           21.533060  ...         13.1
# 32             26.484561           24.168646  ...         10.6
# 33             24.498886           15.367483  ...         10.0
# 34             41.877256           39.422383  ...         13.4
# 35             29.890311           28.290676  ...         15.5
# 36             32.056619           26.977519  ...         15.3
# 37             42.046363           33.253397  ...          8.8
# 38             44.845699           42.613263  ...         18.4
# 39             33.597229           28.698664  ...         14.7
# 40             30.823293           28.062249  ...         23.4
# 41             22.265817           20.549289  ...         22.9
# 42             28.758170           23.311547  ...         14.6
# 43             23.419204           21.662763  ...          6.0
# 44                   NaN                 NaN  ...          NaN
# 45             18.276762           17.493473  ...          8.2
# 46                   NaN                 NaN  ...          NaN
# 47             41.275626           37.767654  ...         17.5
# 48             38.431542           35.485269  ...         17.0
# 49             28.977778           20.711111  ...         20.5
#
#     median_houshold_income  mean_houshold_income  total_housing_units  \
# 0                  19150.0               34044.0               3161.0
# 1                      NaN                   NaN                  NaN
# 2                  14628.0               26129.0               2063.0
# 3                  26094.0               36719.0               1105.0
# 4                  48717.0               58256.0               2427.0
# 5                  24321.0               30035.0               1346.0
# 6                  46809.0               66040.0                564.0
# 7                  18021.0               30864.0               2189.0
# 8                  27868.0               37429.0               2797.0
# 9                  22359.0               35021.0               2005.0
# 10                 31250.0               43242.0                726.0
# 11                 24683.0               33701.0               1398.0
# 12                 30106.0               40341.0               1573.0
# 13                 32788.0               42452.0               1936.0
# 14                 17106.0               35858.0                792.0
# 15                 40586.0               51629.0                382.0
# 16                 43950.0               51118.0               2250.0
# 17                 25500.0               35603.0               2480.0
# 18                 36446.0               48652.0               1406.0
# 19                 21640.0               31081.0               1986.0
# 20                 19079.0               31149.0               2439.0
# 21                 30969.0               40090.0               1103.0
# 22                 17460.0               32913.0               2689.0
# 23                 42193.0               50556.0               1862.0
# 24                 22254.0               31556.0               1376.0
# 25                 43696.0               56775.0               1440.0
# 26                 21723.0               32979.0               1868.0
# 27                 27250.0               43043.0                637.0
# 28                 25244.0               30033.0               2437.0
# 29                 20069.0               30415.0               1471.0
# 30                 28725.0               39908.0               1904.0
# 31                 30783.0               37002.0               1942.0
# 32                 52500.0               65592.0               1873.0
# 33                 35147.0               39140.0               1011.0
# 34                 14301.0               23472.0               1504.0
# 35                 22012.0               36757.0               2345.0
# 36                 20171.0               31557.0               1378.0
# 37                 70774.0               82513.0               1368.0
# 38                 30850.0               36509.0               1720.0
# 39                 21964.0               39463.0               2230.0
# 40                 20621.0               25971.0               2150.0
# 41                 21106.0               31099.0               2039.0
# 42                 29031.0               41682.0               1977.0
# 43                 58125.0               69791.0                960.0
# 44                     NaN                   NaN                  NaN
# 45                 70081.0               91154.0                878.0
# 46                     NaN                   NaN                  NaN
# 47                 22699.0               32176.0               2345.0
# 48                 17825.0               34079.0               2513.0
# 49                 26224.0               46002.0               1354.0
#
#     avg_year_built  occupied_housing_units%  vacant_housing_units%  \
# 0      1953.933724                     94.3                    5.7
# 1              NaN                      NaN                    NaN
# 2      1949.309985                     87.9                   12.1
# 3      1950.578733                     95.8                    4.2
# 4      1961.982489                     96.4                    3.6
# 5      1943.961367                     95.8                    4.2
# 6      1948.276596                     86.9                   13.1
# 7      1957.325491                     92.5                    7.5
# 8      1963.461387                     96.6                    3.4
# 9      1960.547382                     90.2                    9.8
# 10     1961.168044                     90.5                    9.5
# 11     1933.180258                     88.3                   11.7
# 12     1936.143357                     91.0                    9.0
# 13     1929.804752                     85.5                   14.5
# 14     1947.656566                     94.1                    5.9
# 15     1933.701571                     86.1                   13.9
# 16     1961.733333                     91.8                    8.2
# 17     1947.925403                     94.5                    5.5
# 18     1946.310100                     87.4                   12.6
# 19     1962.057905                     92.7                    7.3
# 20     1947.056376                     95.7                    4.3
# 21     1952.487307                     88.8                   11.2
# 22     1968.797508                     97.0                    3.0
# 23     1939.250269                     95.3                    4.7
# 24     1951.457849                     92.3                    7.7
# 25     1969.888889                     98.5                    1.5
# 26     1962.514989                     94.0                    6.0
# 27     1969.845369                     93.2                    6.8
# 28     1947.397005                     91.7                    8.3
# 29     1956.794358                     93.5                    6.5
# 30     1954.504202                     95.4                    4.6
# 31     1951.649846                     88.0                   12.0
# 32     1952.551255                     89.9                   10.1
# 33     1952.504946                     88.8                   11.2
# 34     1971.657580                     92.1                    7.9
# 35     1953.975480                     93.3                    6.7
# 36     1951.452104                     87.2                   12.8
# 37     1956.557749                     91.4                    8.6
# 38     1979.231395                     88.5                   11.5
# 39     1961.112108                     90.6                    9.4
# 40     1956.673023                     92.7                    7.3
# 41     1954.249877                    100.0                    0.0
# 42     1948.992666                     92.9                    7.1
# 43     1947.151042                     89.0                   11.0
# 44             NaN                      NaN                    NaN
# 45     1949.733485                     87.2                   12.8
# 46             NaN                      NaN                    NaN
# 47     1961.052239                     93.6                    6.4
# 48     1941.963191                     91.8                    8.2
# 49     1936.623338                     83.1                   16.9
#
#     total_population  median_age  not_us_citizen%
# 0             8456.0        35.9         9.425260
# 1                NaN         NaN              NaN
# 2             5108.0        27.0        25.078309
# 3             3172.0        32.7        17.559899
# 4             5804.0        39.9         6.805651
# 5             3776.0        28.7        17.743644
# 6             1470.0        39.9        14.761905
# 7             6218.0        25.9         9.295593
# 8             7429.0        34.5         4.536277
# 9             5334.0        29.5        12.635921
# 10            1605.0        40.9         8.161994
# 11            3882.0        32.0        34.544049
# 12            4782.0        28.2        22.626516
# 13            5644.0        28.5        41.654855
# 14            1985.0        39.5        16.473552
# 15            1255.0        32.4        19.043825
# 16            3789.0        51.1         0.686197
# 17            7665.0        28.1        23.222440
# 18            4017.0        30.7        17.649988
# 19            5734.0        28.0        24.101849
# 20            7812.0        27.6        32.757296
# 21            2984.0        30.8        22.788204
# 22            7364.0        27.9        15.942423
# 23            5985.0        30.2        26.182122
# 24            3596.0        28.3        22.608454
# 25            3863.0        40.7         6.290448
# 26            4666.0        30.2        13.480497
# 27            1866.0        31.6        13.612004
# 28            6128.0        28.7        19.810705
# 29            3558.0        38.1         7.279370
# 30            6278.0        29.6        23.192099
# 31            6444.0        30.2        15.254500
# 32            4905.0        36.4         8.909276
# 33            3139.0        25.0        29.372412
# 34            3678.0        26.9         9.053834
# 35            6512.0        31.8        20.070639
# 36            3528.0        31.7        15.164399
# 37            3040.0        42.7         2.631579
# 38            3775.0        32.1        18.701987
# 39            5657.0        29.1         4.419304
# 40            6163.0        24.6        10.157391
# 41            6841.0        31.5        20.040930
# 42            5951.0        30.7        18.803562
# 43            2736.0        38.8         7.346491
# 44               NaN         NaN              NaN
# 45            2249.0        41.5         4.490885
# 46               NaN         NaN              NaN
# 47            6356.0        34.2        23.174953
# 48            6322.0        28.0        16.909206
# 49            3942.0        36.0        13.165906
#
# [50 rows x 23 columns]

# %%
merged_dfs['gas_leaks_per_person'] = merged_dfs['count']/merged_dfs['total_population']

merged_dfs.rename(columns={'engines_assigned_quantity':'avg_assigned_fdny_engines#',
                          'total_incident_duration':'avg_incident_duration'}, inplace = True)
columns = ['incident_year','incident_month','geoid','gas_leaks_per_person']

# %%
merged_dfs = merged_dfs[columns]
merged_dfs[merged_dfs < 0] = None
merged_dfs.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 79776 entries, 0 to 79775
# Data columns (total 4 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   incident_year         79776 non-null  int64
#  1   incident_month        79776 non-null  int64
#  2   geoid                 79776 non-null  int64
#  3   gas_leaks_per_person  63785 non-null  float64
# dtypes: float64(1), int64(3)
# memory usage: 3.0 MB

# %%
merged_dfs = merged_dfs.dropna()
merged_dfs.to_csv(base_path+ 'processed\important_(used_in_app)\Merged_asc_fdny_data_months.csv')

# %%
merged_dfs.head(5000)
# Out:
#       incident_year  incident_month        geoid  gas_leaks_per_person
# 0              2013               1  36005002000              0.000710
# 1              2013               1  36005002400                   inf
# 2              2013               1  36005002500              0.000196
# 3              2013               1  36005002701              0.000631
# 4              2013               1  36005002800              0.000172
# ...             ...             ...          ...                   ...
# 5115           2013               8  36061002700              0.003359
# 5116           2013               8  36061002800              0.000274
# 5117           2013               8  36061003200              0.000393
# 5118           2013               8  36061003601              0.000909
# 5119           2013               8  36061003700              0.001249
#
# [5000 rows x 4 columns]

# %%
merged_dfs.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 63785 entries, 0 to 65446
# Data columns (total 4 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   incident_year         63785 non-null  int64
#  1   incident_month        63785 non-null  int64
#  2   geoid                 63785 non-null  int64
#  3   gas_leaks_per_person  63785 non-null  float64
# dtypes: float64(1), int64(3)
# memory usage: 2.4 MB

# %%
gas_df = pd.read_csv(base_path+ 'processed\important_(used_in_app)\Merged_asc_fdny_data_months.csv')
centers_df = pd.read_csv(
    'https://raw.githubusercontent.com/MarinaOrzechowski/GasLeakConEd/timeline_branch/data/processed/important_(used_in_app)/geoid_with_centers.csv')

# %%
df_selected = gas_df.merge(centers_df, on='geoid')
df_selected = df_selected.groupby(['incident_year', 'incident_month', 'geoid']).agg(
        {'gas_leaks_per_person': 'mean'}).reset_index()
df_selected.head()
# Out:
#    incident_year  incident_month        geoid  gas_leaks_per_person
# 0           2013               1  36005002000              0.000710
# 1           2013               1  36005002400                   inf
# 2           2013               1  36005002500              0.000196
# 3           2013               1  36005002701              0.000631
# 4           2013               1  36005002800              0.000172

# %%
df_selected = df_selected[df_selected['gas_leaks_per_person'] <1000000]

# %%
months = [month for month in range(1, 13)]
df_selected = df_selected.groupby(['incident_year','incident_month']).agg({'gas_leaks_per_person': 'mean'}).reset_index()

[df_selected[(df_selected['incident_year'] == year) & (
    df_selected['incident_month'] == month)].iloc[0]['gas_leaks_per_person'] for month in months]
# Out:
# [0.002257100623390955,
#  0.0026059530957740595,
#  0.0011248553907257557,
#  0.0011507010118710272,
#  0.0024853729568413835,
#  0.003502722318995329,
#  0.0029322065585796063,
#  0.0016937637908488003,
#  0.0021242811756353014,
#  0.0039590416107056405,
#  0.002018956409711787,
#  0.0041142441686094645]

# %%
gas_leaks[2][2]
# Out:
# 0.0011248553907257557

# %% [markdown]
# <h2> Merging without grouping by year </h2>

# %%
import glob
import pandas as pd
import numpy as np
from os import listdir
from os.path import isfile, join

years = [str(i) for i in range(2010, 2019)]
path_from = 'C:\\Users\\mskac\\machineLearning\\GasLeakConEd\\data\\processed\\acs_data\\'
path_to = 'C:\\Users\\mskac\\machineLearning\\GasLeakConEd\\data\\processed\\merged_acs_data\\'
base_path = 'C:/Users/mskac/machineLearning/GasLeakConEd/data/'

files = ['acs_merged_data' + str(year) + '.csv' for year in range(2010, 2019)]

# %%
dfs_acs_original = [pd.read_csv(join(path_to, files[i])) for i in range(3,9)]
for i in range(len(dfs_acs_original)):
    dfs_acs_original[i]['incident_year'] = 2010 +i

# %%
# we will have all years information in one dataframe to merge it with gas info
df_acs = pd.concat(dfs_acs_original, ignore_index = True)
df_acs['geoid'] = df_acs['geoid'].astype('int64')

# %%
df_gas = pd.read_csv(base_path+ 'processed\FULL_fdny_2013_2020.csv')
df_gas['geoid'] = df_gas['geoid'].astype('int64')

# %%
df_gas_ = df_gas[df_gas['incident_date_time'].str[6:10] < '2019']
df_gas_['count'] = 1
df_gas_.head()
# Out:
# C:\Users\mskac\Anaconda3\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#    Unnamed: 0        geoid fire_box  \
# 0           0  36047040000    B4235
# 1           1  36047069602    B3183
# 2           2  36047052000    B2475
# 5           5  36047013000    B1107
# 7           7  36047082600    B1576
#
#                                           ntaname  boroname  \
# 0                                Bensonhurst East  Brooklyn
# 1  Georgetown-Marine Park-Bergen Beach-Mill Basin  Brooklyn
# 2                                        Flatbush  Brooklyn
# 5                                       Bay Ridge  Brooklyn
# 7                                         Erasmus  Brooklyn
#
#        incident_date_time  engines_assigned_quantity  total_incident_duration  \
# 0  01/06/2013 07:05:52 PM                          2                     1035
# 1  01/13/2013 07:21:51 AM                          3                     1469
# 2  07/30/2017 04:40:45 PM                          2                      481
# 5  10/12/2016 05:40:37 PM                          2                     2808
# 7  03/14/2013 12:36:28 AM                          2                      818
#
#    count
# 0      1
# 1      1
# 2      1
# 5      1
# 7      1

# %%
df_gas_ = df_gas_.groupby(['geoid']).agg({'engines_assigned_quantity': 'mean', 'total_incident_duration': 'mean', 'count': 'count'}).reset_index()

# %%
df_gas_.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2139 entries, 0 to 2138
# Data columns (total 4 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   geoid                      2139 non-null   int64
#  1   engines_assigned_quantity  2139 non-null   float64
#  2   total_incident_duration    2139 non-null   float64
#  3   count                      2139 non-null   int64
# dtypes: float64(2), int64(2)
# memory usage: 67.0 KB

# %%
df_acs = df_acs.groupby(['geoid']).agg({'avg_houshold_size':'mean', 'nonfamily_housholds%':'mean',
       'lonely_housholder%':'mean', 'lonely_housholder_over65%':'mean',
       'housholders_grandparents_responsible_for_grandchildren%':'mean',
       'not_us_citizen(abs, people)':'mean', 'unemployed%':'mean','mean_houshold_income':'mean', 'total_housing_units':'mean',
       'avg_year_built':'mean', 'occupied_housing_units%':'mean', 'vacant_housing_units%':'mean',
       'total_population':'mean', 'median_age':'mean', 'not_us_citizen%':'mean'}).reset_index()

# %%
df_acs.head()
# Out:
#          geoid  avg_houshold_size  nonfamily_housholds%  lonely_housholder%  \
# 0  36001000100           2.448333             42.963611           35.744239
# 1  36001000200           2.248333             51.202863           42.489739
# 2  36001000300           2.263333             57.704951           48.334852
# 3  36001000401           1.760000             60.649194           49.845401
# 4  36001000403           2.006667             59.540729           42.288070
#
#    lonely_housholder_over65%  \
# 0                   8.929651
# 1                   7.067291
# 2                  17.599156
# 3                  26.739206
# 4                  12.054417
#
#    housholders_grandparents_responsible_for_grandchildren%  \
# 0                                           4.016257
# 1                                           2.028778
# 2                                           1.423840
# 3                                           0.000000
# 4                                           0.000000
#
#    not_us_citizen(abs, people)  unemployed%  mean_houshold_income  \
# 0                    31.500000    16.133333          42633.166667
# 1                    73.333333     8.750000          46157.333333
# 2                   195.833333    10.583333          47184.166667
# 3                   102.166667     6.500000          83202.666667
# 4                   401.000000     6.350000          72763.833333
#
#    total_housing_units  avg_year_built  occupied_housing_units%  \
# 0           967.333333     1945.516476                85.583333
# 1          2860.500000     1949.423085                73.533333
# 2          2724.333333     1946.564038                87.600000
# 3          1125.000000     1984.511990                91.200000
# 4          2522.166667     1937.131797                89.533333
#
#    vacant_housing_units%  total_population  median_age  not_us_citizen%
# 0              14.416667       2043.333333   35.333333         1.525603
# 1              26.466667       4819.000000   31.450000         1.532343
# 2              12.400000       5606.833333   34.350000         3.469723
# 3               8.800000       2414.166667   63.950000         4.249514
# 4              10.466667       4553.333333   36.200000         8.826881

# %%
merged_dfs = df_acs.merge(df_gas_, how='inner', on = ['geoid'], validate="one_to_one")
merged_dfs = merged_dfs.sort_values(by = ['geoid'])
merged_dfs.columns.to_list()
# Out:
# ['geoid',
#  'avg_houshold_size',
#  'nonfamily_housholds%',
#  'lonely_housholder%',
#  'lonely_housholder_over65%',
#  'housholders_grandparents_responsible_for_grandchildren%',
#  'not_us_citizen(abs, people)',
#  'unemployed%',
#  'mean_houshold_income',
#  'total_housing_units',
#  'avg_year_built',
#  'occupied_housing_units%',
#  'vacant_housing_units%',
#  'total_population',
#  'median_age',
#  'not_us_citizen%',
#  'engines_assigned_quantity',
#  'total_incident_duration',
#  'count']

# %%
merged_dfs['gas_leaks_per_person'] = merged_dfs['count']/merged_dfs['total_population']
merged_dfs['gas_leaks_per_person'] = merged_dfs['count']/merged_dfs['total_population']

merged_dfs.rename(columns={'engines_assigned_quantity':'avg_assigned_fdny_engines#',
                          'total_incident_duration':'avg_incident_duration'}, inplace = True)
columns = ['geoid','gas_leaks_per_person','avg_assigned_fdny_engines#',
 'avg_incident_duration',
 'median_age','avg_houshold_size', 'avg_year_built',
 'nonfamily_housholds%',
 'lonely_housholder%',
 'lonely_housholder_over65%',
 'housholders_grandparents_responsible_for_grandchildren%',
 'unemployed%',
 'mean_houshold_income',
 'total_housing_units',
 'occupied_housing_units%',
 'vacant_housing_units%',
 'not_us_citizen%',
 ]

# %%
merged_dfs = merged_dfs[columns]
merged_dfs[merged_dfs < 0] = None
merged_dfs.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2051 entries, 0 to 2050
# Data columns (total 17 columns):
#  #   Column                                                   Non-Null Count  Dtype
# ---  ------                                                   --------------  -----
#  0   geoid                                                    2051 non-null   int64
#  1   gas_leaks_per_person                                     2051 non-null   float64
#  2   avg_assigned_fdny_engines#                               2051 non-null   float64
#  3   avg_incident_duration                                    2051 non-null   float64
#  4   median_age                                               2041 non-null   float64
#  5   avg_houshold_size                                        2045 non-null   float64
#  6   avg_year_built                                           2051 non-null   float64
#  7   nonfamily_housholds%                                     2051 non-null   float64
#  8   lonely_housholder%                                       2051 non-null   float64
#  9   lonely_housholder_over65%                                2051 non-null   float64
#  10  housholders_grandparents_responsible_for_grandchildren%  2051 non-null   float64
#  11  unemployed%                                              2047 non-null   float64
#  12  mean_houshold_income                                     2039 non-null   float64
#  13  total_housing_units                                      2051 non-null   float64
#  14  occupied_housing_units%                                  2051 non-null   float64
#  15  vacant_housing_units%                                    2051 non-null   float64
#  16  not_us_citizen%                                          2051 non-null   float64
# dtypes: float64(16), int64(1)
# memory usage: 288.4 KB

# %%
merged_dfs.to_csv(base_path+ 'processed\important_(used_in_app)\Merged_asc_fdny_data_all_years.csv')
